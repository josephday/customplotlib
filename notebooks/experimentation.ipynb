# %%
import pandas as pd
import numpy as np
from matplotlib import font_manager as fm

# %%
from customplotlib.base import Customplotlib
plt = Customplotlib()

# %%
plt.plot(x=[1.0,2.0,3.0], y=[1.0,1.5,3.0], label='That')#, color='strong-red')
plt.plot(x=[1.0,2.0,3.0], y=[3.0,2.0,1.0], label='This')#, color='red')

# %%
test_data = pd.DataFrame({'ind': [1,2,3,1,2,3],
                          'dep': [3,2,1,1,1.5,3],
                          'label':['This', 'This', 'This', 'That', 'That', 'That']})

# %%
plt.plot(x='ind', y='dep', data=test_data, label='label')

# %%
ind = test_data['ind']
dep = test_data['dep']
label = test_data['label']
plt.plot(x=ind, y=dep, label=label)

# %%
test_data = pd.DataFrame({'random': np.random.normal(0,1,10),
              'constant': np.random.normal(1,0.05,10),
              'increasing': np.arange(0,10,1) + 100,
              'decreasing': np.arange(10,0,-1),
              'less_steep': np.arange(0,5,0.5) + np.random.normal(0,1,10)})

# %%
test_data
# Out:
#      random  constant  increasing  decreasing  less_steep
# 0 -1.157994  1.043004         100          10    0.685144
# 1 -0.337758  1.030772         101           9    1.402988
# 2 -1.392041  0.911862         102           8    0.639770
# 3 -0.814807  0.933263         103           7    1.941370
# 4  0.178197  1.051705         104           6    0.211826
# 5 -1.769364  0.950246         105           5    3.921895
# 6  0.922048  1.061786         106           4    4.077433
# 7  1.477106  0.984043         107           3    2.879797
# 8 -0.023187  1.044153         108           2    2.288357
# 9  0.049506  1.050618         109           1    3.754088

# %%
plt.matshow(test_data.corr(), gradient='rainbow', invert=True)

# %%
plt.hist(np.random.normal(0,1,10))
# Out:
# (array([2., 1., 0., 1., 2., 0., 2., 1., 0., 1.]),
#  array([-0.86382194, -0.55111564, -0.23840934,  0.07429696,  0.38700326,
#          0.69970957,  1.01241587,  1.32512217,  1.63782847,  1.95053477,
#          2.26324107]),
#  <BarContainer object of 10 artists>)
